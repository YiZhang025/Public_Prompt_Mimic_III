# %%
# In this scripts, you will laern how to do calibartion and zero-shot learning
# We use manual verbalizer and knowledgeable verbalizer as examples.
from tqdm import tqdm
from openprompt.data_utils.text_classification_dataset import AgnewsProcessor
import torch
from openprompt.data_utils.utils import InputExample
from openprompt.trainer import ClassificationRunner

dataset = {}
dataset['train'] = AgnewsProcessor().get_train_examples("../datasets/TextClassification/agnews")
dataset['test'] = AgnewsProcessor().get_test_examples("../datasets/TextClassification/agnews")
from openprompt.plms import load_plm
plm, tokenizer, model_config, WrapperClass = load_plm("roberta", "roberta-large")

# %%
# plm

# %%
# !pip install yacs
# !pip install tensorboardX
# !pip install rouge==1.0.0

# %%
dataset['train']
# Out:
# [{
#    "guid": "0",
#    "label": 2,
#    "meta": {},
#    "text_a": "Wall St. Bears Claw Back Into the Black (Reuters)",
#    "text_b": "Reuters - Short-sellers, Wall Street's dwindling band of ultra-cynics, are seeing green again.",
#    "tgt_text": null
#  },
#  {
#    "guid": "1",
#    "label": 2,
#    "meta": {},
#    "text_a": "Carlyle Looks Toward Commercial Aerospace (Reuters)",
#    "text_b": "Reuters - Private investment firm Carlyle Group, which has a reputation for making well-timed and occasionally controversial plays in the defense industry, has quietly placed its bets on another part of the market.",
#    "tgt_text": null
#  },
#  {
#    "guid": "2",
#    "label": 2,
#    "meta": {},
#    "text_a": "Oil and Economy Cloud Stocks' Outlook (Reuters)",
#    "text_b": "Reuters - Soaring crude prices plus worries about the economy and the outlook for earnings are expected to hang over the stock market next week during the depth of the summer doldrums.",
#    "tgt_text": null
#  },
#  {
#    "guid": "3",
#    "label": 2,
#    "meta": {},
#    "text_a": "Iraq Halts Oil Exports from Main Southern Pipeline (Reuters)",
#    "text_b": "Reuters - Authorities have halted oil export flows from the main pipeline in southern Iraq after intelligence showed a rebel militia could strike infrastructure, an oil official said on Saturday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "4",
#    "label": 2,
#    "meta": {},
#    "text_a": "Oil prices soar to all-time record, posing new menace to US economy (AFP)",
#    "text_b": "AFP - Tearaway world oil prices, toppling records and straining wallets, present a new economic menace barely three months before the US presidential elections.",
#    "tgt_text": null
#  },
#  {
#    "guid": "5",
#    "label": 2,
#    "meta": {},
#    "text_a": "Stocks End Up, But Near Year Lows (Reuters)",
#    "text_b": "Reuters - Stocks ended slightly higher on Friday but stayed near lows for the year as oil prices surged past  #36;46 a barrel, offsetting a positive outlook from computer maker Dell Inc. (DELL.O)",
#    "tgt_text": null
#  },
#  {
#    "guid": "6",
#    "label": 2,
#    "meta": {},
#    "text_a": "Money Funds Fell in Latest Week (AP)",
#    "text_b": "AP - Assets of the nation's retail money market mutual funds fell by  #36;1.17 billion in the latest week to  #36;849.98 trillion, the Investment Company Institute said Thursday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "7",
#    "label": 2,
#    "meta": {},
#    "text_a": "Fed minutes show dissent over inflation (USATODAY.com)",
#    "text_b": "USATODAY.com - Retail sales bounced back a bit in July, and new claims for jobless benefits fell last week, the government said Thursday, indicating the economy is improving from a midsummer slump.",
#    "tgt_text": null
#  },
#  {
#    "guid": "8",
#    "label": 2,
#    "meta": {},
#    "text_a": "Safety Net (Forbes.com)",
#    "text_b": "Forbes.com - After earning a PH.D. in Sociology, Danny Bazil Riley started to work as the general manager at a commercial real estate firm at an annual base salary of  #36;70,000. Soon after, a financial planner stopped by his desk to drop off brochures about insurance benefits available through his employer. But, at 32, \"buying insurance was the furthest thing from my mind,\" says Riley.",
#    "tgt_text": null
#  },
#  {
#    "guid": "9",
#    "label": 2,
#    "meta": {},
#    "text_a": "Wall St. Bears Claw Back Into the Black",
#    "text_b": " NEW YORK (Reuters) - Short-sellers, Wall Street's dwindling  band of ultra-cynics, are seeing green again.",
#    "tgt_text": null
#  },
#  {
#    "guid": "10",
#    "label": 2,
#    "meta": {},
#    "text_a": "Oil and Economy Cloud Stocks' Outlook",
#    "text_b": " NEW YORK (Reuters) - Soaring crude prices plus worries  about the economy and the outlook for earnings are expected to  hang over the stock market next week during the depth of the  summer doldrums.",
#    "tgt_text": null
#  },
#  {
#    "guid": "11",
#    "label": 2,
#    "meta": {},
#    "text_a": "No Need for OPEC to Pump More-Iran Gov",
#    "text_b": " TEHRAN (Reuters) - OPEC can do nothing to douse scorching  oil prices when markets are already oversupplied by 2.8 million  barrels per day (bpd) of crude, Iran's OPEC governor said  Saturday, warning that prices could fall sharply.",
#    "tgt_text": null
#  },
#  {
#    "guid": "12",
#    "label": 2,
#    "meta": {},
#    "text_a": "Non-OPEC Nations Should Up Output-Purnomo",
#    "text_b": " JAKARTA (Reuters) - Non-OPEC oil exporters should consider  increasing output to cool record crude prices, OPEC President  Purnomo Yusgiantoro said on Sunday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "13",
#    "label": 2,
#    "meta": {},
#    "text_a": "Google IPO Auction Off to Rocky Start",
#    "text_b": " WASHINGTON/NEW YORK (Reuters) - The auction for Google  Inc.'s highly anticipated initial public offering got off to a  rocky start on Friday after the Web search company sidestepped  a bullet from U.S. securities regulators.",
#    "tgt_text": null
#  },
#  {
#    "guid": "14",
#    "label": 2,
#    "meta": {},
#    "text_a": "Dollar Falls Broadly on Record Trade Gap",
#    "text_b": " NEW YORK (Reuters) - The dollar tumbled broadly on Friday  after data showing a record U.S. trade deficit in June cast  fresh doubts on the economy's recovery and its ability to draw  foreign capital to fund the growing gap.",
#    "tgt_text": null
#  },
#  {
#    "guid": "15",
#    "label": 2,
#    "meta": {},
#    "text_a": "Rescuing an Old Saver",
#    "text_b": "If you think you may need to help your elderly relatives with their finances, don't be shy about having the money talk -- soon.",
#    "tgt_text": null
#  },
#  {
#    "guid": "16",
#    "label": 2,
#    "meta": {},
#    "text_a": "Kids Rule for Back-to-School",
#    "text_b": "The purchasing power of kids is a big part of why the back-to-school season has become such a huge marketing phenomenon.",
#    "tgt_text": null
#  },
#  {
#    "guid": "17",
#    "label": 2,
#    "meta": {},
#    "text_a": "In a Down Market, Head Toward Value Funds",
#    "text_b": "There is little cause for celebration in the stock market these days, but investors in value-focused mutual funds have reason to feel a bit smug -- if only because they've lost less than the folks who stuck with growth.",
#    "tgt_text": null
#  },
#  {
#    "guid": "18",
#    "label": 2,
#    "meta": {},
#    "text_a": "US trade deficit swells in June",
#    "text_b": "The US trade deficit has exploded 19 to a record  $55.8bn as oil costs drove imports higher, according to a latest figures.",
#    "tgt_text": null
#  },
#  {
#    "guid": "19",
#    "label": 2,
#    "meta": {},
#    "text_a": "Shell 'could be target for Total'",
#    "text_b": "Oil giant Shell could be bracing itself for a takeover attempt, possibly from French rival Total, a  press report claims.",
#    "tgt_text": null
#  },
#  {
#    "guid": "20",
#    "label": 2,
#    "meta": {},
#    "text_a": "Google IPO faces Playboy slip-up",
#    "text_b": "The bidding gets underway for Google's public offering, despite last-minute worries over an interview with its bosses in Playboy magazine.",
#    "tgt_text": null
#  },
#  {
#    "guid": "21",
#    "label": 2,
#    "meta": {},
#    "text_a": "Eurozone economy keeps growing",
#    "text_b": "Official figures show the 12-nation eurozone economy continues to grow, but there are warnings it may slow down later in the year.",
#    "tgt_text": null
#  },
#  {
#    "guid": "22",
#    "label": 2,
#    "meta": {},
#    "text_a": "Expansion slows in Japan",
#    "text_b": "Economic growth in Japan slows down as the country experiences a drop in domestic and corporate spending.",
#    "tgt_text": null
#  },
#  {
#    "guid": "23",
#    "label": 2,
#    "meta": {},
#    "text_a": "Rand falls on shock SA rate cut",
#    "text_b": "Interest rates are trimmed to 7.5 by the South African central bank,  but the lack of warning hits the rand and surprises markets.",
#    "tgt_text": null
#  },
#  {
#    "guid": "24",
#    "label": 2,
#    "meta": {},
#    "text_a": "Car prices down across the board",
#    "text_b": "The cost of buying both new and second hand cars fell sharply over the past five years, a new survey has found.",
#    "tgt_text": null
#  },
#  {
#    "guid": "25",
#    "label": 2,
#    "meta": {},
#    "text_a": "South Korea lowers interest rates",
#    "text_b": "South Korea's central bank cuts interest rates by a quarter percentage point to 3.5 in a bid to drive growth in the economy.",
#    "tgt_text": null
#  },
#  {
#    "guid": "26",
#    "label": 2,
#    "meta": {},
#    "text_a": "Google auction begins on Friday",
#    "text_b": "An auction of shares in Google, the web search engine which could be floated for as much as  $36bn, takes place on Friday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "27",
#    "label": 2,
#    "meta": {},
#    "text_a": "HP shares tumble on profit news",
#    "text_b": "Hewlett-Packard shares fall after disappointing third-quarter profits, while the firm warns the final quarter will also fall short of expectations.",
#    "tgt_text": null
#  },
#  {
#    "guid": "28",
#    "label": 2,
#    "meta": {},
#    "text_a": "Mauritian textile firm cuts jobs",
#    "text_b": "One of the oldest textile operators on the Indian Ocean island of Mauritius last week shut seven factories and cut 900 jobs.",
#    "tgt_text": null
#  },
#  {
#    "guid": "29",
#    "label": 2,
#    "meta": {},
#    "text_a": "Chad seeks refugee aid from IMF",
#    "text_b": "Chad asks the IMF for a loan to pay for looking after more than 100,000 refugees from conflict-torn Darfur in western Sudan.",
#    "tgt_text": null
#  },
#  {
#    "guid": "30",
#    "label": 2,
#    "meta": {},
#    "text_a": "Japan nuclear firm shuts plants",
#    "text_b": "The company running the Japanese nuclear plant hit by a fatal accident is to close its reactors for safety checks.",
#    "tgt_text": null
#  },
#  {
#    "guid": "31",
#    "label": 2,
#    "meta": {},
#    "text_a": "Veteran inventor in market float",
#    "text_b": "Trevor Baylis, the veteran inventor famous for creating the Freeplay clockwork radio, is planning to float his company on the stock market.",
#    "tgt_text": null
#  },
#  {
#    "guid": "32",
#    "label": 2,
#    "meta": {},
#    "text_a": "Saudi Arabia to open up oil taps",
#    "text_b": "Saudi Arabia says it is ready to push an extra 1.3 million barrels a day of oil into the market, to help reverse surging prices.",
#    "tgt_text": null
#  },
#  {
#    "guid": "33",
#    "label": 2,
#    "meta": {},
#    "text_a": "Saudi phone sector gets  $1bn lift",
#    "text_b": "A group led by the UAE's Etisalat plans to spend  $1bn (544m) on expansion after winning two mobile phone licences in Saudi Arabia.",
#    "tgt_text": null
#  },
#  {
#    "guid": "34",
#    "label": 2,
#    "meta": {},
#    "text_a": "Indians fill rail skills shortage",
#    "text_b": "Network Rail flies in specialist Indian engineers to work on the West Coast Mainline because of a UK skills shortage.",
#    "tgt_text": null
#  },
#  {
#    "guid": "35",
#    "label": 2,
#    "meta": {},
#    "text_a": "Steady as they go",
#    "text_b": "BEDFORD -- Scientists at NitroMed Inc. hope their experimental drugs will cure heart disease someday. But lately their focus has been on more mundane matters.",
#    "tgt_text": null
#  },
#  {
#    "guid": "36",
#    "label": 2,
#    "meta": {},
#    "text_a": "Google IPO: Type in 'confusing,' 'secrecy'",
#    "text_b": "I've submitted my bid to buy shares of Google Inc. in the computer search company's giant auction-style initial public offering. That could turn out to be the good news or the bad news.",
#    "tgt_text": null
#  },
#  {
#    "guid": "37",
#    "label": 2,
#    "meta": {},
#    "text_a": "A bargain hunter's paradise",
#    "text_b": "Massachusetts bargain hunters showed up in droves and shopped hard on yesterday's sales tax holiday, buying everything from treadmills and snow blowers to candles and chandeliers, and crediting the 5-percent tax break with bringing them into the stores.",
#    "tgt_text": null
#  },
#  {
#    "guid": "38",
#    "label": 2,
#    "meta": {},
#    "text_a": "Researchers seek to untangle the e-mail thread",
#    "text_b": "E-mail is a victim of its own success. That's the conclusion of IBM Corp. researchers in Cambridge, who have spent nearly a decade conducting field tests at IBM and other companies about how employees work and use electronic mail. It's clear to them that e-mail has become the Internet's killer application.",
#    "tgt_text": null
#  },
#  {
#    "guid": "39",
#    "label": 2,
#    "meta": {},
#    "text_a": "Microsoft Corp. 2.0: a kinder corporate culture",
#    "text_b": "Even a genius can mess up. Bill Gates was a brilliant technologist when he cofounded Microsoft , but as he guided it to greatness in both size and historical consequence, he blundered. He terrorized underlings with his temper and parceled out praise like Scrooge gave to charity. Only the lash inspired the necessary aggressiveness to beat the competition, he thought.",
#    "tgt_text": null
#  },
#  {
#    "guid": "40",
#    "label": 2,
#    "meta": {},
#    "text_a": "Letters",
#    "text_b": "Target the abusers of legal weapons We can all share the outrage, expressed by columnist Steve Bailey (''Summer Sizzler, quot; Aug. 11), at the killings in the city's poor neighborhoods. But there's no need to share his ignorance. He argues for renewal of the so-called assault weapon ban, claiming that otherwise, ''UZIs and AK-47s could again be flooding the streets. quot; His ...",
#    "tgt_text": null
#  },
#  {
#    "guid": "41",
#    "label": 2,
#    "meta": {},
#    "text_a": "Somewhere between gleam and gloom",
#    "text_b": "President Bush has been saying that the US economy has ''turned the corner. quot; Democratic presidential candidate Senator John F. Kerry, in the wake of this month's poor jobs report, quipped that it was more like a U-turn.",
#    "tgt_text": null
#  },
#  {
#    "guid": "42",
#    "label": 2,
#    "meta": {},
#    "text_a": "Technology company sues five ex-employees ",
#    "text_b": "A Marlborough-based technology company is suing five former employees, including three senior managers, for allegedly conspiring against their employer while working on opening a competing business.",
#    "tgt_text": null
#  },
#  {
#    "guid": "43",
#    "label": 2,
#    "meta": {},
#    "text_a": "Grant to aid Lynn Central Square",
#    "text_b": "Central Square in Lynn should be looking a bit brighter. New sidewalks, curbs, fences, lights, landscaping, and road improvements are planned for the Gateway Artisan Block, a key area of the square, with  $830,000 in state grant money given to Lynn last week.",
#    "tgt_text": null
#  },
#  {
#    "guid": "44",
#    "label": 2,
#    "meta": {},
#    "text_a": "State grant to aid Lynn; Bank gives Salem  $10k",
#    "text_b": "Central Square in Lynn should be looking a bit brighter. New sidewalks, curbs, fences, lights, landscaping, and road improvements are planned for the Gateway Artisan Block, a key area of the square, with  $830,000 in state grant money given to Lynn last week.",
#    "tgt_text": null
#  },
#  {
#    "guid": "45",
#    "label": 2,
#    "meta": {},
#    "text_a": "A New Legal Chapter for a 90's Flameout",
#    "text_b": "A lawsuit against Gary Winnick, the former chief of Global Crossing, refocuses attention on what Mr. Winnick knew about his company's finances as it imploded.",
#    "tgt_text": null
#  },
#  {
#    "guid": "46",
#    "label": 2,
#    "meta": {},
#    "text_a": "Will Russia, the Oil Superpower, Flex Its Muscles?",
#    "text_b": "Russia is again emerging as a superpower - but the reason has less to do with nuclear weapons than with oil.",
#    "tgt_text": null
#  },
#  {
#    "guid": "47",
#    "label": 2,
#    "meta": {},
#    "text_a": "Switching Titles, if Not Gears, at Dell",
#    "text_b": "Kevin B. Rollins, the new chief executive of Dell, talks about Dell's transitory slip in customer service, and why he sees a broader technology recovery taking place.",
#    "tgt_text": null
#  },
#  {
#    "guid": "48",
#    "label": 2,
#    "meta": {},
#    "text_a": "For Sale: The Ultimate Status Symbol",
#    "text_b": "With the country in need of cash and rich people dying to show off their wealth, Mr. Stein proposes a unique solution: having the government sell titles of nobility.",
#    "tgt_text": null
#  },
#  {
#    "guid": "49",
#    "label": 2,
#    "meta": {},
#    "text_a": "Quality Gets Swept Away",
#    "text_b": "Quality Distribution is hammered after reporting a large loss for the second quarter.",
#    "tgt_text": null
#  },
#  {
#    "guid": "50",
#    "label": 2,
#    "meta": {},
#    "text_a": "Making Your Insurer Pay",
#    "text_b": "If Hurricane Charley blows your house down, how can you make your insurance company pay?",
#    "tgt_text": null
#  },
#  {
#    "guid": "51",
#    "label": 2,
#    "meta": {},
#    "text_a": "Delightful Dell",
#    "text_b": "The company's results show that it's not grim all over tech world. Just all of it that isn't Dell.",
#    "tgt_text": null
#  },
#  {
#    "guid": "52",
#    "label": 2,
#    "meta": {},
#    "text_a": "Chrysler's Bling King",
#    "text_b": "After a tough year, Detroit's troubled carmaker is back -- thanks to a maverick designer and a car that is dazzling the hip-hop crowd",
#    "tgt_text": null
#  },
#  {
#    "guid": "53",
#    "label": 2,
#    "meta": {},
#    "text_a": "What's Cool In the Pool ... ... And Hot On the Deck",
#    "text_b": "Americans are spending more on tricking out the places where they swim. Here's a look at the new wave of accessories",
#    "tgt_text": null
#  },
#  {
#    "guid": "54",
#    "label": 2,
#    "meta": {},
#    "text_a": "The Age of Doom",
#    "text_b": "In 1993 six geeks had a digital nightmare that changed the culture. It's about to get far creepier",
#    "tgt_text": null
#  },
#  {
#    "guid": "55",
#    "label": 2,
#    "meta": {},
#    "text_a": "Hip Hop's Online Shop",
#    "text_b": "Celebrity fashion is booming. These webpreneurs are bringing it to main street",
#    "tgt_text": null
#  },
#  {
#    "guid": "56",
#    "label": 2,
#    "meta": {},
#    "text_a": "Stoking the Steamroller",
#    "text_b": "No other recording artist can channel American middle-class tastes quite like Chip Davis and his best-selling band",
#    "tgt_text": null
#  },
#  {
#    "guid": "57",
#    "label": 2,
#    "meta": {},
#    "text_a": "Coming to The Rescue",
#    "text_b": "Got a unique problem? Not to worry: you can find a financial planner for every specialized need",
#    "tgt_text": null
#  },
#  {
#    "guid": "58",
#    "label": 2,
#    "meta": {},
#    "text_a": "The New Customers Are In Town",
#    "text_b": "Today's customers are increasingly demanding, in Asia as elsewhere in the world.  Henry Astorga describes the complex reality faced by today's marketers, which includes much higher expectations than we have been used to.  Today's customers want performance, and they want it now! ",
#    "tgt_text": null
#  },
#  {
#    "guid": "59",
#    "label": 2,
#    "meta": {},
#    "text_a": "Barrel of Monkeys, 2004 Edition: Notes on Philippine Elections",
#    "text_b": "Well, it's election time in the Republic of the Philippines, and that means the monkeys are rolling around in those political barrels, having as much fun as they can while laughing their heads off at the strange goings-on that characterize a democratic process loosely based on the American model  but that de facto looks more like a Fellini movie crossed with a Tom and Jerry cartoon - column includes a useful election-year glossary!",
#    "tgt_text": null
#  },
#  {
#    "guid": "60",
#    "label": 2,
#    "meta": {},
#    "text_a": "Oldsmobile: The final parking lot",
#    "text_b": "Why General Motors dropped the Oldsmobile. The four brand  paradoxes GM had to face - the name, the product, image re-positioning, and the consumer - all added up to a brand that had little hope of rebranding.",
#    "tgt_text": null
#  },
#  {
#    "guid": "61",
#    "label": 2,
#    "meta": {},
#    "text_a": "Not All Jobs Belong To The White Man: Asian Minorities, Affirmative Action, And The Quest For Parity At Work",
#    "text_b": "Although a smattering of Chinese, Filipinos, Japanese, Indians, Thais, and others may crow about seeing their kind sitting in prominent positions in corporations and organizations in the USA, these accomplishments become mere cultural high-fives and ritualistic chest-thumping goaded and impishly patronized by 'mainstream society' - the milder and gentler term for the white-dominated populace.",
#    "tgt_text": null
#  },
#  {
#    "guid": "62",
#    "label": 2,
#    "meta": {},
#    "text_a": "Downhome Pinoy Blues, Intersecting Life Paths, and Heartbreak Songs",
#    "text_b": "The Blues is alive and well in the Philippines, as evidenced by this appreciation of the Pinoy Blues band 'Lampano Alley', penned by columnist Clarence Henderson as a counterpoint to his usual economics, business, and culture fare.",
#    "tgt_text": null
#  },
#  {
#    "guid": "63",
#    "label": 2,
#    "meta": {},
#    "text_a": "The Real Time Modern Manila Blues: Bill Monroe Meets Muddy Waters in the Orient",
#    "text_b": "Globalization does strange things to people. A day in the life of a Manila Philippines based business consultant - proving that you really CAN talk about Muddy Walters, bluegrass and work all on the same page...",
#    "tgt_text": null
#  },
#  {
#    "guid": "64",
#    "label": 2,
#    "meta": {},
#    "text_a": "Best Asian Tourism Destinations",
#    "text_b": "The new APMF survey of the best Asian tourism destinations has just kicked off, but it's crowded at the top, with Chiang Mai in Thailand just leading from perennial favourites Hong Kong, Bangkok and Phuket in Thailand, and Bali in  Indonesia. Be one of the first to vote and let us know your reasons.",
#    "tgt_text": null
#  },
#  {
#    "guid": "65",
#    "label": 2,
#    "meta": {},
#    "text_a": "What are the best cities for business in Asia?",
#    "text_b": "One of our new categories in the APMF Sense of Place survey is for best Asian business city. After a couple of days, Singapore leads the pack, followed by Bangkok, Thailand and Hong Kong. Enter your vote and comments and make your views count. More new categories include best city for livability, and best tourism destinations.",
#    "tgt_text": null
#  },
#  {
#    "guid": "66",
#    "label": 2,
#    "meta": {},
#    "text_a": "IT alligator tales",
#    "text_b": "I grew up in New York, where giant alligators -- sometimes more ornately described as albino alligators -- were rumored to roam the citys sewer systems. According to legend, vacationers picked up the tiny crocodilians in Florida, brought them home to New York, and eventually flushed the little buggers when they grew too big for the local concrete jungle.",
#    "tgt_text": null
#  },
#  {
#    "guid": "67",
#    "label": 2,
#    "meta": {},
#    "text_a": "IT Myth 5: Most IT projects fail",
#    "text_b": "Do most IT projects fail? Some point to the number of giant consultancies such as IBM Global Services, Capgemini, and Sapient, who feed off bad experiences encountered by enterprises. Sapient is a company founded on the realization that IT projects are not successful, says Sapient CTO Ben Gaucherin.",
#    "tgt_text": null
#  },
#  {
#    "guid": "68",
#    "label": 2,
#    "meta": {},
#    "text_a": "BEA grabs CA exec to head product group",
#    "text_b": "BEA Systems Inc. has hired the Computer Associates International Inc. executive responsible for CA's Unicenter line of enterprise management software to head BEA's product development group.",
#    "tgt_text": null
#  },
#  {
#    "guid": "69",
#    "label": 2,
#    "meta": {},
#    "text_a": "Autodesk tackles project collaboration",
#    "text_b": "Autodesk  this week unwrapped an updated version of its hosted project collaboration service targeted at the construction and manufacturing industries. Autodesk Buzzsaw lets multiple, dispersed project participants -- including building owners, developers, architects, construction teams, and facility managers -- share and manage data throughout the life of a project, according to Autodesk officials.",
#    "tgt_text": null
#  },
#  {
#    "guid": "70",
#    "label": 2,
#    "meta": {},
#    "text_a": "U.K.'s NHS taps Gartner to help plan  $9B IT overhaul",
#    "text_b": "LONDON -- The U.K.'s National Health Service (NHS) has tapped IT researcher Gartner Inc. to provide market intelligence services as the health organization forges ahead with a mammoth, 5 billion ( $9.2 billion) project to upgrade its information technology infrastructure.",
#    "tgt_text": null
#  },
#  {
#    "guid": "71",
#    "label": 2,
#    "meta": {},
#    "text_a": "Play Boys: Google IPO a Go Anyway",
#    "text_b": "Even though Google's two founders gave an interview to Playboy magazine in the midst of its IPO filing, the SEC allowed the company's offering to go ahead. The boys filed the interview with the SEC and corrected mistakes in it.",
#    "tgt_text": null
#  },
#  {
#    "guid": "72",
#    "label": 2,
#    "meta": {},
#    "text_a": "More Big Boobs in Playboy",
#    "text_b": "An interview with Google's co-founders due out in the current issue of Playboy may delay the company's IPO. Securities regulations restrict what executives can say while preparing to sell stock for the first time.",
#    "tgt_text": null
#  },
#  {
#    "guid": "73",
#    "label": 2,
#    "meta": {},
#    "text_a": "Dutch Firm Beats Apple to Punch",
#    "text_b": "A music retailer from the Netherlands beats Apple by launching a download service in Europe's latest market battleground. Also: Movie industry wrests agreement from defunct company.... Microsoft challenges Photoshop   hellip;. and more.",
#    "tgt_text": null
#  },
#  {
#    "guid": "74",
#    "label": 2,
#    "meta": {},
#    "text_a": "HP to Buy Synstar",
#    "text_b": "Hewlett-Packard will pay  $297 million for the British company. Also: TiVo goes all out to attract customers   hellip;. Sprint offers service guarantees for business wireless subscribers   hellip;. and more.",
#    "tgt_text": null
#  },
#  {
#    "guid": "75",
#    "label": 2,
#    "meta": {},
#    "text_a": "A Personal Operator From Verizon",
#    "text_b": "Verizon plans to offer a service that would act as a virtual switchboard operator, letting customers stay in touch at all times. The program would send phone calls, voicemails and e-mails wherever customers designate. By Elisa Batista.",
#    "tgt_text": null
#  },
#  {
#    "guid": "76",
#    "label": 2,
#    "meta": {},
#    "text_a": "Paid Search Growth May Slow",
#    "text_b": "A new Internet advertising forecast shows a slowdown in paid search listings in the next five years. Will the projection affect Google's prospects when it goes public?",
#    "tgt_text": null
#  },
#  {
#    "guid": "77",
#    "label": 2,
#    "meta": {},
#    "text_a": "Fark Sells Out. France Surrenders",
#    "text_b": "Blogs are the hottest thing on the Net, but are they messing with traditional publishing principles? One of the most popular, Fark.com, is allegedly selling links. Is it the wave of the future? By Daniel Terdiman.",
#    "tgt_text": null
#  },
#  {
#    "guid": "78",
#    "label": 3,
#    "meta": {},
#    "text_a": "'Madden,' 'ESPN' Football Score in Different Ways (Reuters)",
#    "text_b": "Reuters - Was absenteeism a little high on Tuesday among the guys at the office? EA Sports would like to think it was because \"Madden NFL 2005\" came out that day, and some fans of the football simulation are rabid enough to take a sick day to play it.",
#    "tgt_text": null
#  },
#  {
#    "guid": "79",
#    "label": 3,
#    "meta": {},
#    "text_a": "Group to Propose New High-Speed Wireless Format (Reuters)",
#    "text_b": "Reuters - A group of technology companies including Texas Instruments Inc. (TXN.N), STMicroelectronics (STM.PA) and Broadcom Corp. (BRCM.O), on Thursday said they will propose a new wireless networking standard up to 10 times the speed of the current generation.",
#    "tgt_text": null
#  },
#  {
#    "guid": "80",
#    "label": 3,
#    "meta": {},
#    "text_a": "AOL to Sell Cheap PCs to Minorities and Seniors (Reuters)",
#    "text_b": "Reuters - America Online on Thursday said it plans to sell a low-priced PC targeting low-income and minority households who agree to sign up for a year of dialup Internet service.",
#    "tgt_text": null
#  },
#  {
#    "guid": "81",
#    "label": 3,
#    "meta": {},
#    "text_a": "Companies Approve New High-Capacity Disc Format (Reuters)",
#    "text_b": "Reuters - A group of consumer electronics makers said on Wednesday they approved the format for a new generation of discs that can store five times the data of DVDs at the same cost -- enough to put a full season of \"The Sopranos\" on one disc.",
#    "tgt_text": null
#  },
#  {
#    "guid": "82",
#    "label": 3,
#    "meta": {},
#    "text_a": "Missing June Deals Slow to Return for Software Cos. (Reuters)",
#    "text_b": "Reuters - The mystery of what went wrong for the software industry in late June when sales stalled at more than 20 brand-name companies is not even close to being solved although the third quarter is nearly halfway over.",
#    "tgt_text": null
#  },
#  {
#    "guid": "83",
#    "label": 3,
#    "meta": {},
#    "text_a": "Hacker Cracks Apple's Streaming Technology (AP)",
#    "text_b": "AP - The Norwegian hacker famed for developing DVD encryption-cracking software has apparently struck again  #151; this time breaking the locks on Apple Computer Inc.'s wireless music streaming technology.",
#    "tgt_text": null
#  },
#  {
#    "guid": "84",
#    "label": 3,
#    "meta": {},
#    "text_a": "European Download Services Go Mobile (Reuters)",
#    "text_b": "Reuters - The ability to download complete tracks directly over cell-phone networks to mobile phones is becoming a reality in Europe.",
#    "tgt_text": null
#  },
#  {
#    "guid": "85",
#    "label": 3,
#    "meta": {},
#    "text_a": "Open Source Apps Developer SugarCRM Releases Sugar.Sales 1.1 (TechWeb)",
#    "text_b": "TechWeb - News - August 13, 2004",
#    "tgt_text": null
#  },
#  {
#    "guid": "86",
#    "label": 3,
#    "meta": {},
#    "text_a": "Oracle Sales Data Seen Being Released (Reuters)",
#    "text_b": "Reuters - Oracle Corp. sales documents detailing highly confidential information, such as which companies receive discounts on Oracle's business software products and the size of the discounts, are likely to be made public, a federal judge said on Friday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "87",
#    "label": 3,
#    "meta": {},
#    "text_a": "Sun's Looking Glass Provides 3D View (PC World)",
#    "text_b": "PC World - Developers get early code for new operating system 'skin' still being crafted.",
#    "tgt_text": null
#  },
#  {
#    "guid": "88",
#    "label": 3,
#    "meta": {},
#    "text_a": "Apple to open second Japanese retail store this month (MacCentral)",
#    "text_b": "MacCentral - Apple Computer Inc. will open its second Japanese retail store later this month in the western Japanese city of Osaka, it said Thursday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "89",
#    "label": 3,
#    "meta": {},
#    "text_a": "Charley's Force Took Experts by Surprise (AP)",
#    "text_b": "AP - Hurricane Charley's 145-mph force took forecasters by surprise and showed just how shaky a science it still is to predict a storm's intensity  #151; even with all the latest satellite and radar technology.",
#    "tgt_text": null
#  },
#  {
#    "guid": "90",
#    "label": 3,
#    "meta": {},
#    "text_a": "Science, Politics Collide in Election Year (AP)",
#    "text_b": "AP - With more than 4,000 scientists, including 48 Nobel Prize winners, having signed a statement opposing the Bush administration's use of scientific advice, this election year is seeing a new development in the uneasy relationship between science and politics.",
#    "tgt_text": null
#  },
#  {
#    "guid": "91",
#    "label": 3,
#    "meta": {},
#    "text_a": "Building Dedicated to Columbia Astronauts (AP)",
#    "text_b": "AP - A former dormitory converted to classrooms at the Pensacola Naval Air Station was dedicated Friday to two Columbia astronauts who were among the seven who died in the shuttle disaster Feb. 1, 2003.",
#    "tgt_text": null
#  },
#  {
#    "guid": "92",
#    "label": 3,
#    "meta": {},
#    "text_a": "Russian Cargo Craft Docks at Space Station (AP)",
#    "text_b": "AP - A Russian cargo ship docked with the international space station Saturday, bringing food, water, fuel and other items to the two-man Russian-American crew, a space official said.",
#    "tgt_text": null
#  },
#  {
#    "guid": "93",
#    "label": 3,
#    "meta": {},
#    "text_a": "Bangkok's Canals Losing to Urban Sprawl (AP)",
#    "text_b": "AP - Along the banks of the canal, women in rowboats grill fish and sell fresh bananas. Families eat on floating pavilions, rocked gently by waves from passing boats.",
#    "tgt_text": null
#  },
#  {
#    "guid": "94",
#    "label": 3,
#    "meta": {},
#    "text_a": "T. Rex Had Teen Growth Spurt, Scientists Say (Reuters)",
#    "text_b": "Reuters - Tyrannosaurus Rex grew incredibly fast during a teenaged growth spurt that saw the dinosaur expand its bulk by six times, but the fearsome beasts \"lived fast and died young,\" researchers said on Wednesday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "95",
#    "label": 3,
#    "meta": {},
#    "text_a": "Gene Blocker Turns Monkeys Into Workaholics - Study (Reuters)",
#    "text_b": "Reuters - Procrastinating monkeys were turned into workaholics using a gene treatment to block a key brain compound, U.S. researchers reported on Wednesday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "96",
#    "label": 3,
#    "meta": {},
#    "text_a": "Dolphins Too Have Born Socialites (Reuters)",
#    "text_b": "Reuters - Some people are born to be the life and soul of the party -- and so it seems are some dolphins.",
#    "tgt_text": null
#  },
#  {
#    "guid": "97",
#    "label": 3,
#    "meta": {},
#    "text_a": "What's in a Name? Well, Matt Is Sexier Than Paul (Reuters)",
#    "text_b": "Reuters - As Shakespeare said, a rose by any other name would smell as sweet. Right?",
#    "tgt_text": null
#  },
#  {
#    "guid": "98",
#    "label": 3,
#    "meta": {},
#    "text_a": "UK Scientists Allowed to Clone Human Embryos (Reuters)",
#    "text_b": "Reuters - British scientists said on Wednesday they had received permission to clone human embryos for medical research, in what they believe to be the first such license to be granted in Europe.",
#    "tgt_text": null
#  },
#  {
#    "guid": "99",
#    "label": 3,
#    "meta": {},
#    "text_a": "Russian Alien Spaceship Claims Raise Eyebrows, Skepticism (SPACE.com)",
#    "text_b": "SPACE.com - An expedition of Russian researchers claims to have found evidence that an    alien spaceship had something to do with a huge explosion over Siberia in 1908.    Experts in asteroids and comets have long said the massive blast was caused    by a space rock.",
#    "tgt_text": null
#  },
#  {
#    "guid": "100",
#    "label": 3,
#    "meta": {},
#    "text_a": "Comets, Asteroids and Planets around a Nearby Star (SPACE.com)",
#    "text_b": "SPACE.com - A nearby star thought to harbor comets and asteroids now appears to be home to planets, too. The presumed worlds are smaller than Jupiter and could be as tiny as Pluto, new observations suggest.",
#    "tgt_text": null
#  },
#  {
#    "guid": "101",
#    "label": 3,
#    "meta": {},
#    "text_a": "Perseid Meteor Shower Peaks Overnight (SPACE.com)",
#    "text_b": "SPACE.com - A fine display of shooting stars is underway and peaks overnight Wednesday into early Thursday morning. Astronomers expect the 2004 Perseid meteor shower to be one of the best versions of the annual event in several years.",
#    "tgt_text": null
#  },
#  {
#    "guid": "102",
#    "label": 3,
#    "meta": {},
#    "text_a": "Redesigning Rockets: NASA Space Propulsion Finds a New Home (SPACE.com)",
#    "text_b": "SPACE.com - While the exploration of the Moon and other planets in our solar system is nbsp;exciting, the first task for astronauts and robots alike is to actually nbsp;get to those destinations.",
#    "tgt_text": null
#  },
#  {
#    "guid": "103",
#    "label": 3,
#    "meta": {},
#    "text_a": "Studies Find Rats Can Get Hooked on Drugs (AP)",
#    "text_b": "AP - Rats can become drug addicts. That's important to know, scientists say, and has taken a long time to prove. Now two studies by French and British researchers show the animals exhibit the same compulsive drive for cocaine as people do once they're truly hooked.",
#    "tgt_text": null
#  },
#  {
#    "guid": "104",
#    "label": 3,
#    "meta": {},
#    "text_a": "NASA Chief: 'Let's Go Save the Hubble' (SPACE.com)",
#    "text_b": "SPACE.com - Amid uncertainty over the fate of the Hubble Space Telescope and with a key instrument not working, NASA Administrator Sean O'Keefe gave the go-ahead Monday for planning a robotic servicing mission.",
#    "tgt_text": null
#  },
#  {
#    "guid": "105",
#    "label": 3,
#    "meta": {},
#    "text_a": "Armadillo Aerospaces X Prize Prototype Crashes (SPACE.com)",
#    "text_b": "SPACE.com - Armadillo Aerospace of Mesquite, Texas has reported a  crash last weekend of their prototype X Prize rocket.",
#    "tgt_text": null
#  },
#  {
#    "guid": "106",
#    "label": 3,
#    "meta": {},
#    "text_a": "Prairie Dog Won't Be on Endangered List (AP)",
#    "text_b": "AP - The black-tailed prairie dog has been dropped from a list of candidates for the federal endangered species list because scientists have concluded the rodents are no longer threatened.",
#    "tgt_text": null
#  },
#  {
#    "guid": "107",
#    "label": 3,
#    "meta": {},
#    "text_a": "Hubble Trouble: One of Four Instruments Stops Working (SPACE.com)",
#    "text_b": "SPACE.com - One of the four astronomical instruments on the Hubble Space Telescope shut down earlier this week and engineers are trying to pin down the problem. The other three instruments continue to operate normally.",
#    "tgt_text": null
#  },
#  {
#    "guid": "108",
#    "label": 3,
#    "meta": {},
#    "text_a": "Invasive Purple Weed May Meet Its Match (AP)",
#    "text_b": "AP - They burned it, mowed it, sprayed it and flooded it. But nothing killed the purple loosestrife weed, which has become a regional plague, until officials at the Parker River National Wildlife Refuge set a European beetle loose on it.",
#    "tgt_text": null
#  },
#  {
#    "guid": "109",
#    "label": 3,
#    "meta": {},
#    "text_a": "New NASA Supercomputer to Aid Theorists and Shuttle Engineers (SPACE.com)",
#    "text_b": "SPACE.com - NASA researchers have teamed up with a pair of Silicon Valley firms to build    a supercomputer that ranks alongside the world's largest Linux-based systems.",
#    "tgt_text": null
#  },
#  {
#    "guid": "110",
#    "label": 3,
#    "meta": {},
#    "text_a": "Ants Form Supercolony Spanning 60 Miles (AP)",
#    "text_b": "AP - Normally clannish and agressive Argentine ants have become so laid back since arriving in Australia decades ago that they no longer fight neighboring nests and have formed a supercolony here that spans 60 miles, scientists say.",
#    "tgt_text": null
#  },
#  {
#    "guid": "111",
#    "label": 3,
#    "meta": {},
#    "text_a": "Viewer's Guide: Perseid Meteor Shower Peaks Aug. 11-12 (SPACE.com)",
#    "text_b": "SPACE.com - Every August, when many    people are vacationing in the country where skies are dark, the best-known meteor    shower makes its appearance. The annual Perseid meteor shower, as it is called,    promised to put on an above average display this year.",
#    "tgt_text": null
#  },
#  {
#    "guid": "112",
#    "label": 3,
#    "meta": {},
#    "text_a": "Rescuers Free Beached Whale in Brazil (AP)",
#    "text_b": "AP - Rescuers succeeded in freeing a minke whale that washed up on a beach in southeastern Brazil, the fire department said Thursday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "113",
#    "label": 3,
#    "meta": {},
#    "text_a": "Red-Footed Falcon Sighted in Mass. (AP)",
#    "text_b": "AP - A red-footed falcon spotted for the first time in North America is enticing birdwatchers to Martha's Vineyard.",
#    "tgt_text": null
#  },
#  {
#    "guid": "114",
#    "label": 3,
#    "meta": {},
#    "text_a": "Weak Version of Most Powerful Explosions Found (SPACE.com)",
#    "text_b": "SPACE.com - Gamma-ray bursts are the most powerful events in the universe, temporary outshining several galaxies and likely signaling the birth of a black hole.",
#    "tgt_text": null
#  },
#  {
#    "guid": "115",
#    "label": 3,
#    "meta": {},
#    "text_a": "Simultaneous Tropical Storms a Rarity (AP)",
#    "text_b": "AP - The prospect that a tropical storm and a hurricane  #151; or possibly two hurricanes  #151; could strike Florida on the same day is something meteorologists say they have never seen.",
#    "tgt_text": null
#  },
#  {
#    "guid": "116",
#    "label": 3,
#    "meta": {},
#    "text_a": "NASA's Genesis Spacecraft Adjusts Course (AP)",
#    "text_b": "AP - NASA's Genesis spacecraft successfully adjusted its course this week as it heads back toward Earth with a sample of solar wind particles, the space agency said Wednesday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "117",
#    "label": 3,
#    "meta": {},
#    "text_a": "Earth is Rare, New Study Suggests (SPACE.com)",
#    "text_b": "SPACE.com - Flip a coin. Heads, Earth is a common sort of planet. Tails, and ours is as unusual as a coin landing on edge. That's about the state of knowledge for scientists who ponder the question of our planet's rarity.",
#    "tgt_text": null
#  },
#  {
#    "guid": "118",
#    "label": 3,
#    "meta": {},
#    "text_a": "Scientists Probe Pacific for Dead Zone (AP)",
#    "text_b": "AP - His hand on a toggle switch and his eyes on a computer screen, Oregon State University graduate student Anthony Kirincich uses an array of scientific instruments to probe the vibrant waters of the Pacific. He is searching for the absence of life.",
#    "tgt_text": null
#  },
#  {
#    "guid": "119",
#    "label": 3,
#    "meta": {},
#    "text_a": "Life on Mars Likely, Scientist Claims (SPACE.com)",
#    "text_b": "SPACE.com - DENVER, COLORADO -- Those twin robots hard at work on Mars have transmitted teasing views that reinforce the prospect that microbial life may exist on the red planet.",
#    "tgt_text": null
#  },
#  {
#    "guid": "120",
#    "label": 3,
#    "meta": {},
#    "text_a": "India Rethinks Plan to Send Man to Moon (AP)",
#    "text_b": "AP - India is rethinking its plan to send a man to the moon by 2015, as the mission would cost a lot of money and yield very little in return, the national space agency said Thursday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "121",
#    "label": 3,
#    "meta": {},
#    "text_a": "Natural Sunblock: Sun Dims in Strange Ways (SPACE.com)",
#    "text_b": "SPACE.com - When Venus crossed the Sun June 8, showing up as a clear black dot to the delight of millions of skywatchers around the world, astronomers noted something less obvious: The amount of sunlight reaching Earth dipped by 0.1 percent for a few hours.",
#    "tgt_text": null
#  },
#  {
#    "guid": "122",
#    "label": 3,
#    "meta": {},
#    "text_a": "Website Lets Users Scout the Red Planet from Home (SPACE.com)",
#    "text_b": "SPACE.com - For those who want to explore Mars but cant wait for a spacecraft to take them there, NASA scientists have reformulated a website that lets the general public search data and images from previous missions.",
#    "tgt_text": null
#  },
#  {
#    "guid": "123",
#    "label": 3,
#    "meta": {},
#    "text_a": "Appeal Rejected in Trout Restoration Plan (AP)",
#    "text_b": "AP - The U.S. Forest Service on Wednesday rejected environmentalists' appeal of a plan to poison a stream south of Lake Tahoe to aid what wildlife officials call \"the rarest trout in America.\"",
#    "tgt_text": null
#  },
#  {
#    "guid": "124",
#    "label": 3,
#    "meta": {},
#    "text_a": "Explore the Many Colors of Stars (SPACE.com)",
#    "text_b": "SPACE.com - One of the pleasures of    stargazing is noticing and enjoying the various colors that stars display in    dark skies. These hues offer direct visual evidence of how stellar temperatures    vary.",
#    "tgt_text": null
#  },
#  {
#    "guid": "125",
#    "label": 3,
#    "meta": {},
#    "text_a": "Britain Grants Human Cloning License (AP)",
#    "text_b": "AP - Britain granted its first license for human cloning Wednesday, joining South Korea on the leading edge of stem cell research, which is restricted by the Bush administration and which many scientists believe may lead to new treatments for a range of diseases.",
#    "tgt_text": null
#  },
#  {
#    "guid": "126",
#    "label": 3,
#    "meta": {},
#    "text_a": "The Next Great Space Race: SpaceShipOne and Wild Fire to Go For the Gold (SPACE.com)",
#    "text_b": "SPACE.com - A piloted rocket ship race to claim a  #36;10 million Ansari X Prize purse for privately financed flight to the edge of space is heating up.",
#    "tgt_text": null
#  },
#  {
#    "guid": "127",
#    "label": 3,
#    "meta": {},
#    "text_a": "Growth, Mortality of T. Rex Gets Clearer (AP)",
#    "text_b": "AP - Here's a dinosaur finding that parents can appreciate: The teenage Tyrannosaurus rex typically went through an explosive growth spurt, gaining nearly 5 pounds a day.",
#    "tgt_text": null
#  },
#  {
#    "guid": "128",
#    "label": 3,
#    "meta": {},
#    "text_a": "Space Science Pioneer Van Allen Questions Human Spaceflight (SPACE.com)",
#    "text_b": "SPACE.com - A leading space scientist has called to question the validity of human spaceflight, suggesting that sending astronauts outward from Earth is outdated, too costly, and the science returned is trivial.",
#    "tgt_text": null
#  },
#  {
#    "guid": "129",
#    "label": 3,
#    "meta": {},
#    "text_a": "China Begins Manned Space Flight Countdown (AP)",
#    "text_b": "AP - Chinese astronauts are in the final stages of preparing for a manned space mission that will orbit the globe 14 times before returning to Earth, a state-run newspaper reported Thursday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "130",
#    "label": 3,
#    "meta": {},
#    "text_a": "Sunspot Grows to 20 Times Size of Earth (SPACE.com)",
#    "text_b": "SPACE.com - A sunspot group aimed squarely    at Earth has grown to 20 times the size of our planet and has the potential    to unleash a major solar storm.",
#    "tgt_text": null
#  },
#  {
#    "guid": "131",
#    "label": 3,
#    "meta": {},
#    "text_a": "Japanese Lunar Probe Facing Delays (AP)",
#    "text_b": "AP - A lunar orbiter that Japan had planned to launch this year could face further delays, possibly until next year or later, because of a funding shortfall and problems developing the probe's information-gathering capabilities, Japan's space agency said Wednesday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "132",
#    "label": 3,
#    "meta": {},
#    "text_a": "Pollutants From Asia Appear on East Coast (AP)",
#    "text_b": "AP - Scientists looking into air quality and climate change have found pollutants from as far as Asia over New England and the Atlantic.",
#    "tgt_text": null
#  },
#  {
#    "guid": "133",
#    "label": 3,
#    "meta": {},
#    "text_a": "Vietnam's Citadel Vulnerable to Weather (AP)",
#    "text_b": "AP - Experts from Europe and Asia surveyed 1,400-year-old relics of an ancient citadel in Hanoi Tuesday and said they were concerned the priceless antiquities were at risk from exposure to the elements.",
#    "tgt_text": null
#  },
#  {
#    "guid": "134",
#    "label": 3,
#    "meta": {},
#    "text_a": "U.S. Barred From Weakening Dolphin Rules (AP)",
#    "text_b": "AP - In a victory for environmentalists, a federal judge ruled Tuesday that the Bush administration cannot change the standards commercial fisheries must meet before the tuna they catch can carry the \"dolphin-safe\" label.",
#    "tgt_text": null
#  },
#  {
#    "guid": "135",
#    "label": 3,
#    "meta": {},
#    "text_a": "Canadian Robot a Candidate to Save Hubble (AP)",
#    "text_b": "AP - NASA said Tuesday it is moving ahead with plans to send a robot to the rescue of the aging Hubble Space Telescope.",
#    "tgt_text": null
#  },
#  {
#    "guid": "136",
#    "label": 3,
#    "meta": {},
#    "text_a": "Cave Explorers Discover Pit in Croatia (AP)",
#    "text_b": "AP - Cave explorers discovered a pit inside a mountain range in central Croatia believed to have the world's deepest subterranean vertical drop, at nearly 1,700 feet, a scientific institute reported Monday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "137",
#    "label": 3,
#    "meta": {},
#    "text_a": "Aquarium Reviews Death of Dolphin (AP)",
#    "text_b": "AP - The chief scientist at the National Aquarium in Baltimore has launched a review of the dolphin breeding program after the death of a 4-month-old dolphin.",
#    "tgt_text": null
#  },
#  {
#    "guid": "138",
#    "label": 3,
#    "meta": {},
#    "text_a": "Scientists Seek Better Way to Measure Rain (AP)",
#    "text_b": "AP - Meteorologists at North Carolina State University are working on a way to more accurately measure rainfall in small areas.",
#    "tgt_text": null
#  },
#  {
#    "guid": "139",
#    "label": 3,
#    "meta": {},
#    "text_a": "Wash. State Team's Private Rocket Explodes (AP)",
# ...
#    "tgt_text": null
#  },
#  {
#    "guid": "955",
#    "label": 0,
#    "meta": {},
#    "text_a": "Delegates Urge Al-Sadr to Leave Shrine",
#    "text_b": "NAJAF, Iraq - U.S. tanks rolled into the Old City of Najaf toward a holy Shiite shrine where militants were hiding Monday as participants at a national conference voted to send a delegation here to try to negotiate an end to the fighting...",
#    "tgt_text": null
#  },
#  {
#    "guid": "956",
#    "label": 0,
#    "meta": {},
#    "text_a": "Bush Announces Plan for Troop Realignment",
#    "text_b": "WASHINGTON - President Bush on Monday announced plans to shift 60,000 to 70,000 U.S. troops who are now stationed in Europe and Asia in one of the largest troop realignments since the end of the Cold War...",
#    "tgt_text": null
#  },
#  {
#    "guid": "957",
#    "label": 3,
#    "meta": {},
#    "text_a": "'SP2' a Must For XP Users (washingtonpost.com)",
#    "text_b": "washingtonpost.com - To get an idea of how Windows got to be such a mess, think of it as a house that was built on an island in the middle of a lake, deep in the countryside.",
#    "tgt_text": null
#  },
#  {
#    "guid": "958",
#    "label": 3,
#    "meta": {},
#    "text_a": "Rough patches for Microsoft's SP2",
#    "text_b": "Windows update doesn't play well with all applications, even Redmond's. Also: CNET Reviews on security work still to be done.",
#    "tgt_text": null
#  },
#  {
#    "guid": "959",
#    "label": 1,
#    "meta": {},
#    "text_a": "Bryant Defense Wins Ruling",
#    "text_b": "In another setback to the prosecution in the Kobe Bryant sexual assault case, the court maintains ruling that allows information about the accuser's sex life into court.",
#    "tgt_text": null
#  },
#  {
#    "guid": "960",
#    "label": 2,
#    "meta": {},
#    "text_a": "Stocks Up, Oil Price Ease Gives Relief",
#    "text_b": " NEW YORK (Reuters) - U.S. stocks climbed on Monday, getting  a boost from lower oil prices after Venezuela's president  declared he had survived a recall referendum, easing fears  about the country's oil exports.",
#    "tgt_text": null
#  },
#  {
#    "guid": "961",
#    "label": 2,
#    "meta": {},
#    "text_a": "KMart Posts Profit; Cash Hits  $2.6 Bln",
#    "text_b": " CHICAGO (Reuters) - Kmart Holdings Corp. &lt;A HREF=\"http://www.investor.reuters.com/FullQuote.aspx?ticker=KMRT.O target=/stocks/quickinfo/fullquote\"&gt;KMRT.O&lt;/A&gt; on Monday  reported its third consecutive quarterly profit and boosted its  cash pile to  $2.6 billion as it cut spending on advertising and  discounts, sending its stock up 14 percent.",
#    "tgt_text": null
#  },
#  {
#    "guid": "962",
#    "label": 3,
#    "meta": {},
#    "text_a": "Personal Tech: Cybersecurity",
#    "text_b": "Fast Forward columnist Rob Pegoraro will be online to talk about The Washington Post's special cybersecurity report.",
#    "tgt_text": null
#  },
#  {
#    "guid": "963",
#    "label": 3,
#    "meta": {},
#    "text_a": "PivX hardens Windows with Qwik-Fix Pro",
#    "text_b": "PivX Solutions, Inc. of Newport Beach, California, on Monday announced the availability of Qwik-Fix Pro, an intrusion prevention software product for Windows machines that disables or modifies features of Microsoft Corp. Windows and the Internet Explorer (IE) Web browser that are frequent targets of malicious computer hackers and virus writers.",
#    "tgt_text": null
#  },
#  {
#    "guid": "964",
#    "label": 2,
#    "meta": {},
#    "text_a": "No Respite for Microsoft",
#    "text_b": "European antitrust regulators extend their review of Microsoft-Time Warner deal. Also: Gateway plans to sell desktops at CompUSA   hellip;. Vodafone's Japanese unit headhunts an executive from rival NTT DoCoMo   hellip;. and more.",
#    "tgt_text": null
#  },
#  {
#    "guid": "965",
#    "label": 2,
#    "meta": {},
#    "text_a": "Overland Bullish on Tech",
#    "text_b": "Investors are dumping tech stocks with abandon. As for Overland Storage, it is a buyer.",
#    "tgt_text": null
#  },
#  {
#    "guid": "966",
#    "label": 3,
#    "meta": {},
#    "text_a": "Plurality of Worlds in the Universe",
#    "text_b": "Did the same Greek philosophers who declared the first truce for Olympic competition have the foresight to imagine a universe not just where many countries could coexist, but also a universe occupied by many such habitable worlds?",
#    "tgt_text": null
#  },
#  {
#    "guid": "967",
#    "label": 3,
#    "meta": {},
#    "text_a": "CompUSA Agrees to Sell Gateway PCs (PC World)",
#    "text_b": "PC World - Desktop systems will be available in 226 stores across the U.S.",
#    "tgt_text": null
#  },
#  {
#    "guid": "968",
#    "label": 2,
#    "meta": {},
#    "text_a": "Lowe's Reports 18 Pct. Hike in Profits",
#    "text_b": " ATLANTA (Reuters) - Lowe's Cos. &lt;A HREF=\"http://www.investor.reuters.com/FullQuote.aspx?ticker=LOW.N target=/stocks/quickinfo/fullquote\"&gt;LOW.N&lt;/A&gt;, the world's No. 2  home improvement retailer, on Monday reported an 18 percent  increase in second-quarter profit and said earnings for the  rest of the year would top current estimates.",
#    "tgt_text": null
#  },
#  {
#    "guid": "969",
#    "label": 2,
#    "meta": {},
#    "text_a": "Toymakers' Stocks Hit Lows on Downgrade",
#    "text_b": " NEW YORK (Reuters) - Shares of top toy maker Mattel Inc.  &lt;A HREF=\"http://www.investor.reuters.com/FullQuote.aspx?ticker=MAT.N target=/stocks/quickinfo/fullquote\"&gt;MAT.N&lt;/A&gt; and rival Hasbro Inc. &lt;A HREF=\"http://www.investor.reuters.com/FullQuote.aspx?ticker=HAS.N target=/stocks/quickinfo/fullquote\"&gt;HAS.N&lt;/A&gt; fell to their lowest  levels at least 14 months on Monday after a downgrade by Lehman  Brothers, which cited deteriorating industry conditions.",
#    "tgt_text": null
#  },
#  {
#    "guid": "970",
#    "label": 3,
#    "meta": {},
#    "text_a": "Microsoft ships updated Works",
#    "text_b": "Version 8 of the low-priced productivity package includes a stand-alone dictionary and a PowerPoint add-on.",
#    "tgt_text": null
#  },
#  {
#    "guid": "971",
#    "label": 3,
#    "meta": {},
#    "text_a": "Briefly: FaceTime pulls in  $16 million",
#    "text_b": "roundup Plus: Bladed desktop pioneer gets  $25 million...AOL kicks off free fantasy sports...HP partners with 3G gear maker.",
#    "tgt_text": null
#  },
#  {
#    "guid": "972",
#    "label": 3,
#    "meta": {},
#    "text_a": "Microsoft, Time Warner DRM buy on EU review shelf",
#    "text_b": "Regulators could still launch an investigation into the two titans' acquisition of ContentGuard this month.",
#    "tgt_text": null
#  },
#  {
#    "guid": "973",
#    "label": 3,
#    "meta": {},
#    "text_a": "Ex-Polaroid exec takes top finance job at 3Com",
#    "text_b": "Donald Halsted, one target of a class-action suit alleging financial improprieties at bankrupt Polaroid, officially becomes CFO.",
#    "tgt_text": null
#  },
#  {
#    "guid": "974",
#    "label": 3,
#    "meta": {},
#    "text_a": "Intel delays first TV chip",
#    "text_b": "In another setback, the chipmaker says a processor for large-screen projection TVs won't come out this year.",
#    "tgt_text": null
#  },
#  {
#    "guid": "975",
#    "label": 3,
#    "meta": {},
#    "text_a": "Sybase upgrades PowerBuilder, plots RFID move",
#    "text_b": "Sybase Inc. released a new version of its application development tool on Monday, called PowerBuilder 10, and outlined plans for an upgrade to its database software, Adaptive Server Enterprise, which will go into beta at the end of this month and is due for release next year.",
#    "tgt_text": null
#  },
#  {
#    "guid": "976",
#    "label": 3,
#    "meta": {},
#    "text_a": "Infocus: Detecting Worms and Abnormal Activities with NetFlow, Part 1",
#    "text_b": "This paper discusses the use of NetFlow, a traffic profile monitoring technology available on many routers, for use in the early detection of worms, spammers, and other abnormal network activity in large enterprise networks and service providers.",
#    "tgt_text": null
#  },
#  {
#    "guid": "977",
#    "label": 1,
#    "meta": {},
#    "text_a": "Escobedo Keeps U.S. Unbeaten in Boxing (AP)",
#    "text_b": "AP - They washed cars, put up posters and sold T-shirts to raise the money to be here. When it was finally time for Vicente Escobedo to fight, his family and friends welcomed him into the arena by waving his picture and chanting \"Chente, Chente.\"",
#    "tgt_text": null
#  },
#  {
#    "guid": "978",
#    "label": 1,
#    "meta": {},
#    "text_a": "Chronology of Key Events in Kobe Bryant (AP)",
#    "text_b": "AP - Timeline of the sexual assault case against Los Angeles Lakers star Kobe Bryant:",
#    "tgt_text": null
#  },
#  {
#    "guid": "979",
#    "label": 1,
#    "meta": {},
#    "text_a": "Blackhawks Re-Sign Defenseman Berard",
#    "text_b": " Chicago, Ill. (Sports Network) - The Chicago Blackhawks  Monday agreed to terms on a one-year contract with defenseman  Bryan Berard. As per team policy, financial terms of the deal  were not disclosed.",
#    "tgt_text": null
#  },
#  {
#    "guid": "980",
#    "label": 0,
#    "meta": {},
#    "text_a": "India makes elephants appeal",
#    "text_b": "Indian asks Bangladesh to spare the lives of around 100 elephants which have strayed across the border.",
#    "tgt_text": null
#  },
#  {
#    "guid": "981",
#    "label": 0,
#    "meta": {},
#    "text_a": "Murder search police make arrest",
#    "text_b": "Police investigating the murder of newlywed Chanel Taylor make an arrest.",
#    "tgt_text": null
#  },
#  {
#    "guid": "982",
#    "label": 0,
#    "meta": {},
#    "text_a": "Bush Announces Plan to Realign Thousands of Troops",
#    "text_b": "President Bush today announced plans to shift 60,000 to 70,000 U.S. troops who are now stationed in Europe and Asia.",
#    "tgt_text": null
#  },
#  {
#    "guid": "983",
#    "label": 0,
#    "meta": {},
#    "text_a": "Bush Announces Plan for Troop Realignment",
#    "text_b": "CINCINNATI - President Bush on Monday announced plans to shift as many as 70,000 U.S. troops who are now stationed in Western Europe and Asia in one of the largest realignments since the end of the Cold War...",
#    "tgt_text": null
#  },
#  {
#    "guid": "984",
#    "label": 0,
#    "meta": {},
#    "text_a": "Jackson Squares Off With Attorney",
#    "text_b": "SANTA MARIA, Calif. - Fans of Michael Jackson erupted in cheers Monday as the pop star emerged from a double-decker tour bus and went into court for a showdown with the prosecutor who has pursued him for years on child molestation charges...",
#    "tgt_text": null
#  },
#  {
#    "guid": "985",
#    "label": 3,
#    "meta": {},
#    "text_a": "Does That Web Site Look Phishy? (PC World)",
#    "text_b": "PC World - WholeSecurity's new software claims to identify fraudulent sites.",
#    "tgt_text": null
#  },
#  {
#    "guid": "986",
#    "label": 3,
#    "meta": {},
#    "text_a": "Product Review: Nokia 6820 Wireless Messaging Handset (NewsFactor)",
#    "text_b": "NewsFactor - The Nokia (NYSE: NOK) 6820 is an ergonomically pleasing handheld device that integrates short text, multimedia and  instant messaging capabilities with all of the features and functions that one normally would expect to find in a dedicated GSM/GPRS cellular phone.",
#    "tgt_text": null
#  },
#  {
#    "guid": "987",
#    "label": 3,
#    "meta": {},
#    "text_a": "Sprint Broadens Its Vision (NewsFactor)",
#    "text_b": "NewsFactor - Sprint (NYSE: FON) is taking its mobile-data services to the next level, targeting both consumers and business customers, as the carrier rolls out the Sprint TV multimedia service and adds the popular  BlackBerry e-mail application to its portfolio.",
#    "tgt_text": null
#  },
#  {
#    "guid": "988",
#    "label": 3,
#    "meta": {},
#    "text_a": "Microsoft Lists XP SP2 Problems (NewsFactor)",
#    "text_b": "NewsFactor - With automatic download of Microsoft's (Nasdaq: MSFT) enormous SP2 security patch to the Windows XP operating system set to begin, the industry still waits to understand its ramifications. Home users that have their preferences set to receive operating-system updates as they are made available by Microsoft may be surprised to learn that some of the software they already run on their systems could be disabled by SP2 or may run very differently.",
#    "tgt_text": null
#  },
#  {
#    "guid": "989",
#    "label": 0,
#    "meta": {},
#    "text_a": "2 More Turkish Men Taken Hostage in Iraq (AP)",
#    "text_b": "AP - Armed assailants attacked a convoy of Turkish trucks delivering supplies to U.S. forces in Iraq and took two Turkish drivers hostage, their company said Monday.",
#    "tgt_text": null
#  },
#  {
#    "guid": "990",
#    "label": 3,
#    "meta": {},
#    "text_a": "Group to Talk Coal-Bed Methane Drilling (AP)",
#    "text_b": "AP - Dozens of scientists plan to converge at the University of Wyoming to talk about West Nile virus, water pollution and other issues related to coal-bed methane drilling.",
#    "tgt_text": null
#  },
#  {
#    "guid": "991",
#    "label": 3,
#    "meta": {},
#    "text_a": "FDA Approves New Device to Clear Blood Clots",
#    "text_b": "By DIEDTRA HENDERSON    WASHINGTON (AP) -- The first device to remove blood clots from the brains of people suffering strokes - a new treatment option that could save lives and shave the  $53 billion annual bill to treat strokes, has been approved by the government.    In 80 percent of strokes, a blood vessel in the brain becomes clogged by a blood clot, increasing the chance of severe disability or death...",
#    "tgt_text": null
#  },
#  {
#    "guid": "992",
#    "label": 3,
#    "meta": {},
#    "text_a": "Briefly: Sprint to bake in BlackBerry",
#    "text_b": "roundup Plus: Microsoft ships updated Works...FaceTime pulls in  $16 million...Bladed desktop pioneer gets  $25 million.",
#    "tgt_text": null
#  },
#  {
#    "guid": "993",
#    "label": 3,
#    "meta": {},
#    "text_a": "Former Polaroid exec takes top finance job at 3Com",
#    "text_b": "Donald Halsted, one target of a class action suit alleging financial improprieties at bankrupt Polaroid, officially becomes CFO.",
#    "tgt_text": null
#  },
#  {
#    "guid": "994",
#    "label": 3,
#    "meta": {},
#    "text_a": "Sprint to bake in BlackBerry for businesses",
#    "text_b": "Research In Motion's BlackBerry e-mail and data services will be carried on Sprint's networks.",
#    "tgt_text": null
#  },
#  {
#    "guid": "995",
#    "label": 2,
#    "meta": {},
#    "text_a": "U.S. Stocks Rebound as Oil Prices Ease",
#    "text_b": " NEW YORK (Reuters) - U.S. stocks rebounded on Monday as oil  prices retreated from their highs, while upbeat earnings  announcements from retailers fueled the improved sentiment.",
#    "tgt_text": null
#  },
#  {
#    "guid": "996",
#    "label": 2,
#    "meta": {},
#    "text_a": "Dollar Rises Vs Euro After Asset Data",
#    "text_b": " NEW YORK (Reuters) - The dollar gained against the euro on  Monday after a report on flows into U.S. assets showed enough  of a rise in foreign investments to offset the current account  gap for the month.",
#    "tgt_text": null
#  },
#  {
#    "guid": "997",
#    "label": 3,
#    "meta": {},
#    "text_a": "Bikes Bring Internet to Indian Villagers (AP)",
#    "text_b": "AP - For 12-year-old Anju Sharma, hope for a better life arrives in her poor farming village three days a week on a bicycle rickshaw that carries a computer with a high-speed, wireless Internet connection.",
#    "tgt_text": null
#  },
#  {
#    "guid": "998",
#    "label": 3,
#    "meta": {},
#    "text_a": "Celebrity Chefs Are Everywhere in Vegas",
#    "text_b": "By ADAM GOLDMAN    LAS VEGAS (AP) -- The waiter appears tableside in the cozy dining room laden with oil paintings, stained glass and hints of cherry and oak. Before reciting the day's special menu items, he recounts the restaurant's devotion to farm-fresh produce and tosses out a morsel about its namesake, chef Bradley Ogden...",
#    "tgt_text": null
#  },
#  {
#    "guid": "999",
#    "label": 3,
#    "meta": {},
#    "text_a": "Entertainment World Wary of Microsoft Technology",
#    "text_b": "By GARY GENTILE    LOS ANGELES (AP) -- CinemaNow Inc., the Internet-based movie service, is a rarity in Hollywood - a company that eagerly embraces Microsoft Corp. (MSFT) technology and relies on it exclusively to transmit, protect and display the movies it rents to customers...",
#    "tgt_text": null
#  },
#  ...]

# %%
from openprompt.prompts import ManualTemplate
mytemplate = ManualTemplate(tokenizer=tokenizer).from_file("../scripts/TextClassification/agnews/manual_template.txt", choice=0)

from openprompt import PromptDataLoader



# ## Define the verbalizer
from openprompt.prompts import ManualVerbalizer, KnowledgeableVerbalizer

# this is a user provided set of label words?
myverbalizer = KnowledgeableVerbalizer(tokenizer, num_classes=4).from_file("../scripts/TextClassification/agnews/knowledgeable_verbalizer.txt")

# %%
len(myverbalizer.label_words)
# Out:
# 4

# %%
mytemplate.text
# Out:
# [{'add_prefix_space': ' ', 'text': 'A'},
#  {'add_prefix_space': ' ', 'mask': None},
#  {'add_prefix_space': ' ', 'text': 'news :'},
#  {'add_prefix_space': ' ', 'placeholder': 'text_a'},
#  {'add_prefix_space': ' ', 'placeholder': 'text_b'}]

# %%
# load promptforclassification model class

from openprompt import PromptForClassification
promptModel = PromptForClassification(
    template = mytemplate,
    plm = plm,
    verbalizer = myverbalizer,
)

# %%
promptModel
# Out:
# PromptForClassification(
#   (prompt_model): PromptModel(
#     (plm): RobertaForMaskedLM(
#       (roberta): RobertaModel(
#         (embeddings): RobertaEmbeddings(
#           (word_embeddings): Embedding(50265, 1024, padding_idx=1)
#           (position_embeddings): Embedding(514, 1024, padding_idx=1)
#           (token_type_embeddings): Embedding(1, 1024)
#           (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder): RobertaEncoder(
#           (layer): ModuleList(
#             (0): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (1): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (2): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (3): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (4): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (5): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (6): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (7): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (8): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (9): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (10): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (11): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (12): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (13): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (14): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (15): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (16): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (17): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (18): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (19): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (20): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (21): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (22): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (23): RobertaLayer(
#               (attention): RobertaAttention(
#                 (self): RobertaSelfAttention(
#                   (query): Linear(in_features=1024, out_features=1024, bias=True)
#                   (key): Linear(in_features=1024, out_features=1024, bias=True)
#                   (value): Linear(in_features=1024, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#                 (output): RobertaSelfOutput(
#                   (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                   (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                 )
#               )
#               (intermediate): RobertaIntermediate(
#                 (dense): Linear(in_features=1024, out_features=4096, bias=True)
#               )
#               (output): RobertaOutput(
#                 (dense): Linear(in_features=4096, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#       )
#       (lm_head): RobertaLMHead(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (decoder): Linear(in_features=1024, out_features=50265, bias=True)
#       )
#     )
#     (template): ManualTemplate()
#   )
#   (verbalizer): KnowledgeableVerbalizer()
# )

# %%
use_cuda = True
if use_cuda:
    promptModel = promptModel.cuda()

# %%
# prompt data loader

from openprompt import PromptDataLoader
train_dataloader = PromptDataLoader(
    dataset = dataset['train'],
    tokenizer = tokenizer, 
    template = mytemplate, 
    tokenizer_wrapper_class=WrapperClass,
    max_seq_length=512, decoder_max_length=3
)

test_dataloader = PromptDataLoader(
    dataset = dataset['test'],
    tokenizer = tokenizer, 
    template = mytemplate, 
    tokenizer_wrapper_class=WrapperClass,
    max_seq_length=512, decoder_max_length=3
)
# Out:
# tokenizing: 120000it [01:49, 1099.42it/s]
# tokenizing: 7600it [00:06, 1142.69it/s]

# %%
# learning rate and optimizer
# Now the training is standard
from transformers import  AdamW, get_linear_schedule_with_warmup
loss_func = torch.nn.CrossEntropyLoss()
no_decay = ['bias', 'LayerNorm.weight']
# it's always good practice to set no decay to biase and LayerNorm parameters
optimizer_grouped_parameters = [
    {'params': [p for n, p in promptModel.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in promptModel.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]

optimizer = AdamW(optimizer_grouped_parameters, lr=1e-4)

# %%
def fit(model, train_dataloader, val_dataloader, loss_func, optimizer, epochs = 5, cuda = True):
    best_score = 0.0
    for epoch in range(epochs):
        train_epoch(model, train_dataloader, loss_func, optimizer, epoch, cuda = True)
        score = evaluate(model, val_dataloader)
        if score > best_score:
            best_score = score
    return best_score
        

def train_epoch(model, train_dataloader, loss_func, optimizer, epoch, cuda = True):
    model.train()
    tot_loss = 0
    pbar = tqdm(test_dataloader)
    for step, inputs in enumerate(pbar):
        if cuda:            
            inputs = inputs.cuda()
        logits = model(inputs)
        labels = inputs['label']
        loss = loss_func(logits, labels)
        tot_loss += loss.item()
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        
        if step %500 ==1:
            print("Epoch {}, average loss: {}".format(epoch, tot_loss/(step+1)), flush=True)

def evaluate(model, val_dataloader, cuda = True):
    model.eval()
    allpreds = []
    alllabels = []
    with torch.no_grad():
        for step, inputs in enumerate(val_dataloader):
            if cuda:
                
                inputs = inputs.cuda()
            logits = model(inputs)
            labels = inputs['label']
            alllabels.extend(labels.cpu().tolist())
            allpreds.extend(torch.argmax(logits, dim=-1).cpu().tolist())
    acc = sum([int(i==j) for i,j in zip(allpreds, alllabels)])/len(allpreds)
    print(f"accuracy was: {acc}")
    return acc

# %%
# # run training
# for epoch in range(1):
#     tot_loss = 0 
#     for step, inputs in enumerate(train_dataloader):
#         if use_cuda:
#             inputs = inputs.cuda()
#         logits = promptModel(inputs)
#         labels = inputs['label']
#         loss = loss_func(logits, labels)
#         loss.backward()
#         tot_loss += loss.item()
#         optimizer.step()
#         optimizer.zero_grad()
#         if step %100 ==1:
#             print("Epoch {}, average loss: {}".format(epoch, tot_loss/(step+1)), flush=True)

# %%
score = fit(promptModel, train_dataloader, test_dataloader, loss_func, optimizer, cuda = True)


test_score = evaluate(promptModel, test_dataloader)
print(f"Test score was: {test_score}")
# Out:
#   0%|          | 1/7600 [00:00<52:08,  2.43it/s]
# Epoch 0, average loss: 2.115755945444107
#   7%|▋         | 501/7600 [02:24<34:23,  3.44it/s]
# Epoch 0, average loss: 1.4125970934145304
#  13%|█▎        | 1001/7600 [04:49<31:57,  3.44it/s]
# Epoch 0, average loss: 1.4071743588669008
#  20%|█▉        | 1501/7600 [07:15<29:32,  3.44it/s]
# Epoch 0, average loss: 1.4061938241980623
#  26%|██▋       | 2001/7600 [09:40<27:11,  3.43it/s]
# Epoch 0, average loss: 1.407970487110034
#  33%|███▎      | 2501/7600 [12:05<24:38,  3.45it/s]
# Epoch 0, average loss: 1.407215945933845
#  39%|███▉      | 3001/7600 [14:30<22:13,  3.45it/s]
# Epoch 0, average loss: 1.4068375364195786
#  46%|████▌     | 3501/7600 [16:55<19:52,  3.44it/s]
# Epoch 0, average loss: 1.4077252219655365
#  53%|█████▎    | 4001/7600 [19:20<17:23,  3.45it/s]
# Epoch 0, average loss: 1.4057508843131605
#  59%|█████▉    | 4501/7600 [21:46<15:00,  3.44it/s]
# Epoch 0, average loss: 1.4054806423990667
#  63%|██████▎   | 4803/7600 [23:13<13:34,  3.44it/s]
